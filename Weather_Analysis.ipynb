# %% [markdown]
# # 🌦️ Weather Data Analysis of India

# %% [markdown]
# ### Problem Statement
# The project analyzes multi-year historical climate data across `24 major cities` representing all geographic regions of India to capture nationwide weather variability. Using multi-variable meteorological data, the study `identifies long-term climate trends, regional seasonal patterns, and extreme weather events such as heatwaves and heavy rainfall`. The project also examines `interactions between atmospheric, hydrological, and land-surface variables to understand climate system behavior`. The goal is to build data-driven insights and risk indicators to support climate monitoring and environmental analysis.

# %% [markdown]
# # 🇮🇳 Cities Covered — Grouped by Region
#
# ## 🧭 North India
# - Delhi
# - Srinagar
# - Ladakh
# - Amritsar
# - Manali
# - Nainital
# - Lucknow
#
# ## 🌅 East India
# - Patna
# - Kolkata (Calcutta)
#
# ## 🌧️ Northeast India
# - Guwahati
# - Agartala
# - Geku
#
# ## 🌵 West India
# - Ahmedabad
# - Jaisalmer
# - Mumbai
#
# ## 🌾 Central India
# - Kota
# - Jabalpur
# - Nagpur
#
# ## 🌴 South India
# - Chennai
# - Bengaluru
# - Hyderabad
# - Visakhapatnam
# - Udupi
# - Thiruvananthapuram
#
# ---
#
# ### 📌 Notes
# - Cities are grouped based on broad geographic regions used in climatology and weather analysis.
# - Some locations (e.g., **Ladakh**) represent larger geographic regions rather than a single city.
# - Kolkata and Calcutta refer to the same city; the modern name **Kolkata** is used here.
# - Regional grouping is used to support comparative climate analysis across diverse weather systems.

# %% [markdown]
# # 🪨 Column Descriptions
#
# | Variable | Unit | Description |
# |---|---|---|
# | **time** | ISO8601 (date) | Date of the observation (daily timestamp). |
# | **weather_code** | WMO code | The most severe weather condition on a given day |
# | **temperature_2m_max** | °C | Maximum daily air temperature at 2 meters above ground |
# | **temperature_2m_min** | °C | Minimum daily air temperature at 2 meters above ground |
# | **temperature_2m_mean** | °C | Mean daily air temperature at 2 meters above ground (daily average). |
# | **apparent_temperature_max** | °C | Maximum daily apparent (feels-like) temperature |
# | **apparent_temperature_min** | °C | Minimum daily apparent (feels-like) temperature |
# | **sunshine_duration** | seconds | Number of seconds of sunshine per day (direct irradiance > 120 W/m², WMO definition). This is typically less than daylight duration due to dawn and dusk. |
# | **daylight_duration** | seconds | Total number of daylight seconds per day |
# | **sunrise** | ISO8601 | Sunrise time |
# | **sunset** | ISO8601 | Sunset time |
# | **precipitation_sum** | mm | Total daily precipitation (rain, showers, and snowfall) |
# | **rain_sum** | mm | Total daily rainfall |
# | **snowfall_sum** | cm | Total daily snowfall |
# | **precipitation_hours** | hours | Number of hours with precipitation |
# | **shortwave_radiation_sum** | MJ/m² | Total daily incoming shortwave solar radiation |
# | **wind_direction_10m_dominant** | ° | Dominant wind direction |
# | **wind_speed_10m_max** | km/h | Maximum wind speed at 10 meters above ground |
# | **wind_speed_10m_min** | km/h | Minimum daily wind speed at 10 meters above ground |
# | **wind_speed_10m_mean** | km/h | Mean daily wind speed at 10 meters above ground |
# | **et0_fao_evapotranspiration** | mm | Daily reference evapotranspiration (ET₀) for a well-watered grass field (FAO standard) |
# | **cloud_cover_max** | % | Maximum total cloud cover during the day (0–100%). |
# | **cloud_cover_min** | % | Minimum total cloud cover during the day (0–100%). |
# | **cloud_cover_mean** | % | Mean daily total cloud cover (0–100%). |
# | **soil_moisture_0_to_100cm_mean** | m³/m³ | Mean volumetric soil water content averaged from surface to 100 cm depth. |
# | **soil_temperature_0_to_100cm_mean** | °C | Mean soil temperature averaged from surface to 100 cm depth. |
# | **dew_point_2m_min** | °C | Minimum daily dew point temperature at 2 meters above ground. |
# | **dew_point_2m_max** | °C | Maximum daily dew point temperature at 2 meters above ground. |
# | **dew_point_2m_mean** | °C | Mean daily dew point temperature at 2 meters above ground. |
# | **wet_bulb_temperature_2m_min** | °C | Minimum daily wet-bulb temperature at 2 meters above ground. |
# | **wet_bulb_temperature_2m_max** | °C | Maximum daily wet-bulb temperature at 2 meters above ground. |
# | **wet_bulb_temperature_2m_mean** | °C | Mean daily wet-bulb temperature at 2 meters above ground. |
# | **relative_humidity_2m_min** | % | Minimum daily relative humidity at 2 meters above ground. |
# | **relative_humidity_2m_max** | % | Maximum daily relative humidity at 2 meters above ground. |
# | **relative_humidity_2m_mean** | % | Mean daily relative humidity at 2 meters above ground. |
# | **surface_pressure_min** | hPa | Minimum daily surface air pressure. |
# | **surface_pressure_max** | hPa | Maximum daily surface air pressure. |
# | **pressure_msl_min** | hPa | Minimum daily mean sea-level pressure (MSL). |
# | **pressure_msl_max** | hPa | Maximum daily mean sea-level pressure (MSL). |
# | **pressure_msl_mean** | hPa | Mean daily mean sea-level pressure (MSL). |
# | **latitude** | decimal degrees | Latitude of the location. |
# | **longitude** | decimal degrees | Longitude of the location. |
# | **location_id** | — | Unique identifier assigned to each location in the dataset. |
#
# ---
#
# ## 📌 Notes
# - Temperature values are measured at **2 meters** above ground level.
# - Wind values are measured at **10 meters** above ground level.
# - Times are provided in **ISO 8601** format.
# - Cloud cover is expressed as **percentage of sky covered by clouds (0–100%)**.
# - Soil variables represent **layer-averaged values from 0–100 cm depth**.

# %%
# Library imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Combine the 3 dataframes into one and export as a single file

# %%
df_part1= pd.read_csv(r'weather_data_7_locations.csv')
df_part2= pd.read_csv(r'weather_data_8_locations.csv')
df_part3= pd.read_csv(r'weather_data_9_locations.csv')


# On viewing the csv, we find that df_part1 is of the format yyyy-mm-dd and df_part2 and df_part3 are both of the format dd-mm-yyyy.
# So we convert df_part1 to match the format of the other two and the merge them into single dataset

df_part1["time"] = pd.to_datetime(df_part1["time"], format="%Y-%m-%d")
df_part1["time"] = df_part1["time"].dt.strftime("%d-%m-%Y")                 # convert format to dd-mm-yyyy
df_part1.head()
# Out:
#          time  weather_code  temperature_2m_max  temperature_2m_min  \
# 0  01-01-2018             0                24.4                11.4
# 1  02-01-2018             0                22.8                 8.6
# 2  03-01-2018             0                22.9                10.3
# 3  04-01-2018             0                24.4                 8.1
# 4  05-01-2018             0                24.0                 9.9
#
#    apparent_temperature_max  apparent_temperature_min  sunshine_duration  \
# 0                      23.5                      10.1           35208.99
# 1                      20.5                       7.1           35233.59
# 2                      20.4                       8.2           35260.27
# 3                      22.0                       5.7           35289.14
# 4                      22.4                       8.7           35320.67
#
#    daylight_duration           sunrise            sunset  ...  \
# 0           38161.03  2018-01-01T07:12  2018-01-01T17:48  ...
# 1           38183.40  2018-01-02T07:12  2018-01-02T17:48  ...
# 2           38207.68  2018-01-03T07:12  2018-01-03T17:49  ...
# 3           38233.86  2018-01-04T07:12  2018-01-04T17:50  ...
# 4           38262.24  2018-01-05T07:13  2018-01-05T17:50  ...
#
#    relative_humidity_2m_mean  soil_temperature_0_to_100cm_mean  \
# 0                         56                              21.0
# 1                         56                              20.8
# 2                         55                              20.5
# 3                         56                              20.3
# 4                         58                              20.2
#
#    wind_speed_10m_min  wind_speed_10m_mean  wet_bulb_temperature_2m_min  \
# 0                 2.4                  7.0                          8.9
# 1                 3.2                  5.9                          7.5
# 2                 1.6                  6.0                          7.6
# 3                 2.6                  7.6                          7.0
# 4                 1.3                  5.2                          8.5
#
#    wet_bulb_temperature_2m_max  wet_bulb_temperature_2m_mean   latitude  \
# 0                         15.4                          11.6  25.202108
# 1                         12.4                           9.8  25.202108
# 2                         12.0                           9.7  25.202108
# 3                         12.9                          10.1  25.202108
# 4                         14.3                          11.2  25.202108
#
#    longitude  location_id
# 0   75.80994            1
# 1   75.80994            1
# 2   75.80994            1
# 3   75.80994            1
# 4   75.80994            1
#
# [5 rows x 43 columns]

# %%
# Now we can merge all 3 df_parts into one single dataset 
combined_df= pd.concat([df_part1, df_part2, df_part3], ignore_index= True)
print("The dataset has been combined into a single dataset with", combined_df.shape[0], "rows")

# export the combined dataset
# combined_df.to_csv('complete_weather_data.csv', index= False)
# Out:
# The dataset has been combined into a single dataset with 80000 rows

# %% [markdown]
# # ▶️ Import combined dataset

# %%
# Import the complete combined dataset
df= pd.read_csv(r'complete_weather_data.csv')
df.head(10)
# Out:
#          time  weather_code  temperature_2m_max  temperature_2m_min  \
# 0  01-01-2018             0                24.4                11.4
# 1  02-01-2018             0                22.8                 8.6
# 2  03-01-2018             0                22.9                10.3
# 3  04-01-2018             0                24.4                 8.1
# 4  05-01-2018             0                24.0                 9.9
# 5  06-01-2018             0                23.8                10.6
# 6  07-01-2018             0                23.4                 9.4
# 7  08-01-2018             0                23.5                 9.2
# 8  09-01-2018             0                24.0                10.2
# 9  10-01-2018             0                24.3                10.5
#
#    apparent_temperature_max  apparent_temperature_min  sunshine_duration  \
# 0                      23.5                      10.1           35208.99
# 1                      20.5                       7.1           35233.59
# 2                      20.4                       8.2           35260.27
# 3                      22.0                       5.7           35289.14
# 4                      22.4                       8.7           35320.67
# 5                      22.1                      10.3           35354.65
# 6                      21.8                       8.0           35391.00
# 7                      21.5                       7.0           35429.62
# 8                      22.0                       8.6           35470.45
# 9                      21.9                       9.5           35505.58
#
#    daylight_duration           sunrise            sunset  ...  \
# 0           38161.03  2018-01-01T07:12  2018-01-01T17:48  ...
# 1           38183.40  2018-01-02T07:12  2018-01-02T17:48  ...
# 2           38207.68  2018-01-03T07:12  2018-01-03T17:49  ...
# 3           38233.86  2018-01-04T07:12  2018-01-04T17:50  ...
# 4           38262.24  2018-01-05T07:13  2018-01-05T17:50  ...
# 5           38292.87  2018-01-06T07:13  2018-01-06T17:51  ...
# 6           38325.67  2018-01-07T07:13  2018-01-07T17:52  ...
# 7           38360.57  2018-01-08T07:13  2018-01-08T17:52  ...
# 8           38397.51  2018-01-09T07:13  2018-01-09T17:53  ...
# 9           38436.40  2018-01-10T07:13  2018-01-10T17:54  ...
#
#    relative_humidity_2m_mean  soil_temperature_0_to_100cm_mean  \
# 0                       56.0                              21.0
# 1                       56.0                              20.8
# 2                       55.0                              20.5
# 3                       56.0                              20.3
# 4                       58.0                              20.2
# 5                       59.0                              20.2
# 6                       52.0                              20.2
# 7                       50.0                              20.2
# 8                       50.0                              20.1
# 9                       46.0                              20.0
#
#    wind_speed_10m_min  wind_speed_10m_mean  wet_bulb_temperature_2m_min  \
# 0                 2.4                  7.0                          8.9
# 1                 3.2                  5.9                          7.5
# 2                 1.6                  6.0                          7.6
# 3                 2.6                  7.6                          7.0
# 4                 1.3                  5.2                          8.5
# 5                 0.4                  4.8                          9.9
# 6                 0.8                  4.5                          7.9
# 7                 1.3                  5.2                          7.3
# 8                 2.9                  5.2                          8.0
# 9                 1.0                  3.3                          8.8
#
#    wet_bulb_temperature_2m_max  wet_bulb_temperature_2m_mean   latitude  \
# 0                         15.4                          11.6  25.202108
# 1                         12.4                           9.8  25.202108
# 2                         12.0                           9.7  25.202108
# 3                         12.9                          10.1  25.202108
# 4                         14.3                          11.2  25.202108
# 5                         13.6                          11.2  25.202108
# 6                         12.8                          10.4  25.202108
# 7                         12.6                          10.0  25.202108
# 8                         12.9                          10.2  25.202108
# 9                         12.9                          10.6  25.202108
#
#    longitude  location_id
# 0   75.80994            1
# 1   75.80994            1
# 2   75.80994            1
# 3   75.80994            1
# 4   75.80994            1
# 5   75.80994            1
# 6   75.80994            1
# 7   75.80994            1
# 8   75.80994            1
# 9   75.80994            1
#
# [10 rows x 43 columns]

# %%
# Check data type of time column
df['time'].dtype
# Out:
# dtype('O')

# %%
# Convert 'time' column from String to DateTime
df['time']= pd.to_datetime(df['time'], format="%d-%m-%Y")
df['time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   time                              80000 non-null  datetime64[ns]
#  1   weather_code                      80000 non-null  int64
#  2   temperature_2m_max                80000 non-null  float64
#  3   temperature_2m_min                80000 non-null  float64
#  4   apparent_temperature_max          80000 non-null  float64
#  5   apparent_temperature_min          80000 non-null  float64
#  6   sunshine_duration                 80000 non-null  float64
#  7   daylight_duration                 80000 non-null  float64
#  8   sunrise                           80000 non-null  object
#  9   sunset                            80000 non-null  object
#  10  precipitation_sum                 80000 non-null  float64
#  11  rain_sum                          80000 non-null  float64
#  12  snowfall_sum                      80000 non-null  float64
#  13  precipitation_hours               80000 non-null  float64
#  14  shortwave_radiation_sum           80000 non-null  float64
#  15  wind_direction_10m_dominant       80000 non-null  int64
#  16  wind_speed_10m_max                80000 non-null  float64
#  17  et0_fao_evapotranspiration        80000 non-null  float64
#  18  cloud_cover_max                   80000 non-null  int64
#  19  cloud_cover_min                   80000 non-null  int64
#  20  temperature_2m_mean               80000 non-null  float64
#  21  cloud_cover_mean                  80000 non-null  int64
#  22  soil_moisture_0_to_100cm_mean     80000 non-null  float64
#  23  dew_point_2m_mean                 80000 non-null  float64
#  24  dew_point_2m_max                  80000 non-null  float64
#  25  dew_point_2m_min                  80000 non-null  float64
#  26  surface_pressure_min              80000 non-null  float64
#  27  surface_pressure_max              80000 non-null  float64
#  28  pressure_msl_min                  80000 non-null  float64
#  29  pressure_msl_max                  80000 non-null  float64
#  30  pressure_msl_mean                 80000 non-null  float64
#  31  relative_humidity_2m_min          80000 non-null  int64
#  32  relative_humidity_2m_max          80000 non-null  int64
#  33  relative_humidity_2m_mean         50776 non-null  float64
#  34  soil_temperature_0_to_100cm_mean  80000 non-null  float64
#  35  wind_speed_10m_min                80000 non-null  float64
#  36  wind_speed_10m_mean               80000 non-null  float64
#  37  wet_bulb_temperature_2m_min       80000 non-null  float64
#  38  wet_bulb_temperature_2m_max       80000 non-null  float64
#  39  wet_bulb_temperature_2m_mean      80000 non-null  float64
#  40  latitude                          80000 non-null  float64
#  41  longitude                         80000 non-null  float64
#  42  location_id                       80000 non-null  int64
# dtypes: datetime64[ns](1), float64(32), int64(8), object(2)
# memory usage: 26.2+ MB

# %% [markdown]
# > We can see that relative_humidity_2m_mean has around 30k null values. Let us confirm it too

# %%
df.isna().sum()
# Out:
# time                                    0
# weather_code                            0
# temperature_2m_max                      0
# temperature_2m_min                      0
# apparent_temperature_max                0
# apparent_temperature_min                0
# sunshine_duration                       0
# daylight_duration                       0
# sunrise                                 0
# sunset                                  0
# precipitation_sum                       0
# rain_sum                                0
# snowfall_sum                            0
# precipitation_hours                     0
# shortwave_radiation_sum                 0
# wind_direction_10m_dominant             0
# wind_speed_10m_max                      0
# et0_fao_evapotranspiration              0
# cloud_cover_max                         0
# cloud_cover_min                         0
# temperature_2m_mean                     0
# cloud_cover_mean                        0
# soil_moisture_0_to_100cm_mean           0
# dew_point_2m_mean                       0
# dew_point_2m_max                        0
# dew_point_2m_min                        0
# surface_pressure_min                    0
# surface_pressure_max                    0
# pressure_msl_min                        0
# pressure_msl_max                        0
# pressure_msl_mean                       0
# relative_humidity_2m_min                0
# relative_humidity_2m_max                0
# relative_humidity_2m_mean           29224
# soil_temperature_0_to_100cm_mean        0
# wind_speed_10m_min                      0
# wind_speed_10m_mean                     0
# wet_bulb_temperature_2m_min             0
# wet_bulb_temperature_2m_max             0
# wet_bulb_temperature_2m_mean            0
# latitude                                0
# longitude                               0
# location_id                             0
# dtype: int64

# %% [markdown]
# > The only column with null values is 'relative_humidity_2m' with 29224 missing values
#
# Since we do not have hourly values, so we cannot calculate the true mean value for each day. Also we cannot drop the null rows because we would almost lose **37%** of the data. The best way to go around is to make an estimation and since we have columns for **min and max humidity** so we can calculate an estimate mean value using the following formula:
#
# >**mean = (max+min)/2**
#
# This is valid because **min <= mean <= max**

# %%
df['relative_humidity_2m_mean'] = df['relative_humidity_2m_mean'].fillna((df['relative_humidity_2m_max']-df['relative_humidity_2m_min']) / 2)

# check null values again
print("Null values in 'relative_humidity_2m_mean':", df['relative_humidity_2m_mean'].isna().sum())
print("Null values in dataset:", df.isna().sum().sum())
# Out:
# Null values in 'relative_humidity_2m_mean': 0
# Null values in dataset: 0

# %% [markdown]
# > Now we can see that there are no null values left in **relative_humidity_2m_mean** column and in whole table

# %%
# Rename 'time' as 'date' and set it as index of the dataset
df.rename(columns= {'time' : 'date'}, inplace= True)
df.set_index('date', inplace= True)

# %%
# Check if 'date' is set as index
df.index.name
# Out:
# 'date'

# %%
# Check if there are any missing day in the dataset

full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
missing_timestamps = full_index.difference(df.index)
print('Expected days:', len(full_index))
print('Actual rows:', len(df))
print('Missing timestamps count:', len(missing_timestamps))
# Out:
# Expected days: 3653
# Actual rows: 80000
# Missing timestamps count: 0

# %% [markdown]
# > There are no missing records for any day over 10 years' data for each city

# %%
df['sunshine_duration']
# Out:
# date
# 2018-01-01    35208.99
# 2018-01-02    35233.59
# 2018-01-03    35260.27
# 2018-01-04    35289.14
# 2018-01-05    35320.67
#                 ...
# 2025-12-27    35425.53
# 2025-12-28    35460.70
# 2025-12-29    35496.11
# 2025-12-30    35531.70
# 2025-12-31    35567.36
# Name: sunshine_duration, Length: 80000, dtype: float64

# %%
#Convert 'sunlight_duration' and 'daylight_duration' from seconds to hours for each day

df['sunshine_duration'] = df['sunshine_duration'] / 3600
df['daylight_duration'] = df['daylight_duration'] / 3600
df['sunshine_duration']
# Out:
# date
# 2018-01-01    9.780275
# 2018-01-02    9.787108
# 2018-01-03    9.794519
# 2018-01-04    9.802539
# 2018-01-05    9.811297
#                 ...
# 2025-12-27    9.840425
# 2025-12-28    9.850194
# 2025-12-29    9.860031
# 2025-12-30    9.869917
# 2025-12-31    9.879822
# Name: sunshine_duration, Length: 80000, dtype: float64

# %%
sunshine_compare=pd.DataFrame()
sunshine_compare[['sunshine_before(sec)', 'daylight_before(sec)']]= df[['sunshine_duration', 'daylight_duration']]
sunshine_compare
# Out:
#             sunshine_before(sec)  daylight_before(sec)
# date
# 2018-01-01              9.780275             10.600286
# 2018-01-02              9.787108             10.606500
# 2018-01-03              9.794519             10.613244
# 2018-01-04              9.802539             10.620517
# 2018-01-05              9.811297             10.628400
# ...                          ...                   ...
# 2025-12-27              9.840425             10.854178
# 2025-12-28              9.850194             10.857011
# 2025-12-29              9.860031             10.860294
# 2025-12-30              9.869917             10.864028
# 2025-12-31              9.879822             10.868211
#
# [80000 rows x 2 columns]

# %%
df[['sunset', 'sunrise']]
# Out:
#                       sunset           sunrise
# date
# 2018-01-01  2018-01-01T17:48  2018-01-01T07:12
# 2018-01-02  2018-01-02T17:48  2018-01-02T07:12
# 2018-01-03  2018-01-03T17:49  2018-01-03T07:12
# 2018-01-04  2018-01-04T17:50  2018-01-04T07:12
# 2018-01-05  2018-01-05T17:50  2018-01-05T07:13
# ...                      ...               ...
# 2025-12-27  2025-12-27T17:40  2025-12-27T06:49
# 2025-12-28  2025-12-28T17:40  2025-12-28T06:49
# 2025-12-29  2025-12-29T17:41  2025-12-29T06:49
# 2025-12-30  2025-12-30T17:42  2025-12-30T06:50
# 2025-12-31  2025-12-31T17:42  2025-12-31T06:50
#
# [80000 rows x 2 columns]

# %% [markdown]
# > Sunset time has date which is getting redundant as we already have `date` as a separate column. So let's remove the date from the `sunset` column and set it as `datetime` data type. We do the same for 'sunrise' column as well

# %%
#Convert type to datetime and extract only the time and remove date from the values

df['sunrise'] = pd.to_datetime(df['sunrise']).dt.strftime('%H:%M')
df['sunset'] = pd.to_datetime(df['sunset']).dt.strftime('%H:%M')

df[['sunrise', 'sunset']]
# Out:
#            sunrise sunset
# date
# 2018-01-01   07:12  17:48
# 2018-01-02   07:12  17:48
# 2018-01-03   07:12  17:49
# 2018-01-04   07:12  17:50
# 2018-01-05   07:13  17:50
# ...            ...    ...
# 2025-12-27   06:49  17:40
# 2025-12-28   06:49  17:40
# 2025-12-29   06:49  17:41
# 2025-12-30   06:50  17:42
# 2025-12-31   06:50  17:42
#
# [80000 rows x 2 columns]

# %% [markdown]
# > We also see that on combining the 3 different parts of main dataset, we get unsorted data with respect to 'date'. So let us sort the dataset as per 'date' for each record

# %%
df= df.sort_index()
df.head()
# Out:
#             weather_code  temperature_2m_max  temperature_2m_min  \
# date
# 2016-01-01             3                23.4                10.4
# 2016-01-01             3                25.6                13.5
# 2016-01-01             3                 6.4                -3.3
# 2016-01-01             3                19.8                 8.9
# 2016-01-01             0                32.8                19.8
#
#             apparent_temperature_max  apparent_temperature_min  \
# date
# 2016-01-01                      24.1                       9.4
# 2016-01-01                      24.0                      12.9
# 2016-01-01                       2.8                      -7.6
# 2016-01-01                      18.3                       7.3
# 2016-01-01                      35.1                      20.3
#
#             sunshine_duration  daylight_duration sunrise sunset  \
# date
# 2016-01-01           9.481967          10.483414   06:54  17:23
# 2016-01-01          10.366233          11.375169   06:41  18:04
# 2016-01-01           8.125781          10.080264   07:22  17:26
# 2016-01-01           9.217025          10.124981   07:29  17:37
# 2016-01-01          10.051794          11.001144   07:11  18:11
#
#             precipitation_sum  ...  relative_humidity_2m_mean  \
# date                           ...
# 2016-01-01                0.0  ...                       26.5
# 2016-01-01                0.0  ...                       69.0
# 2016-01-01                0.0  ...                       10.0
# 2016-01-01                0.0  ...                       21.5
# 2016-01-01                0.0  ...                       57.0
#
#             soil_temperature_0_to_100cm_mean  wind_speed_10m_min  \
# date
# 2016-01-01                              20.8                 0.5
# 2016-01-01                              21.9                 7.9
# 2016-01-01                               6.7                 1.1
# 2016-01-01                              16.3                 0.4
# 2016-01-01                              27.8                 0.4
#
#             wind_speed_10m_mean  wet_bulb_temperature_2m_min  \
# date
# 2016-01-01                  5.8                          9.9
# 2016-01-01                 12.6                         12.7
# 2016-01-01                  3.1                         -6.8
# 2016-01-01                  3.8                          7.5
# 2016-01-01                  8.9                         16.9
#
#             wet_bulb_temperature_2m_max  wet_bulb_temperature_2m_mean  \
# date
# 2016-01-01                         16.1                          13.1
# 2016-01-01                         16.5                          14.8
# 2016-01-01                          0.9                          -3.9
# 2016-01-01                         12.9                           9.9
# 2016-01-01                         22.2                          19.5
#
#              latitude  longitude  location_id
# date
# 2016-01-01  26.818980   80.93023            6
# 2016-01-01  12.970123   77.56364            5
# 2016-01-01  32.161686   77.15840            4
# 2016-01-01  31.599297   74.91018            3
# 2016-01-01  19.086115   72.85291            2
#
# [5 rows x 42 columns]

# %% [markdown]
# **Extracting Unique Coordinates for City Mapping**
#
# > To add a 'cities' column to our main dataset, we first need to identify all the unique geographical locations. In this step, we extract the distinct `latitude` and `longitude` pairs and store them in a new, smaller DataFrame (`unique_coordinates`). This will serve as our reference table to map these coordinates to their actual city names.

# %%
unique_coordinates=df[['latitude','longitude']].drop_duplicates().reset_index(drop=True)
unique_coordinates
# Out:
#      latitude  longitude
# 0   26.818980  80.930230
# 1   12.970123  77.563640
# 2   32.161686  77.158400
# 3   31.599297  74.910180
# 4   19.086115  72.852910
# 5   23.022846  72.601880
# 6   29.420034  79.503460
# 7   28.646748  77.274800
# 8   13.110721  80.245900
# 9   34.059753  74.812500
# 10   8.471002  76.932980
# 11  26.959578  70.921196
# 12  17.398945  78.457085
# 13  17.680140  83.204254
# 14  33.989452  77.977530
# 15  21.124779  79.115850
# 16  13.321617  74.794520
# 17  28.435852  95.113630
# 18  23.866430  91.238100
# 19  25.202108  75.809940
# 20  25.623900  85.108696
# 21  26.186290  91.776320
# 22  23.163443  79.916230
# 23  22.530754  88.319500

# %%
len(unique_coordinates)
# Out:
# 24

# %% [markdown]
# > We can see that there are 24 unique locations in the dataset.

# %%
# Dictionary mapping (latitude, longitude) to City Names
city_mapping = {
    (8.471002, 76.932980): 'Thiruvananthapuram',
    (12.970123, 77.563640): 'Bengaluru',
    (13.110721, 80.245900): 'Chennai',
    (13.321617, 74.794520): 'Udupi',
    (17.398945, 78.457085): 'Hyderabad',
    (17.680140, 83.204254): 'Visakhapatnam',
    (19.086115, 72.852910): 'Mumbai',
    (21.124779, 79.115850): 'Nagpur',
    (22.530754, 88.319500): 'Kolkata',
    (23.022846, 72.601880): 'Ahmedabad',
    (23.163443, 79.916230): 'Jabalpur',
    (23.866430, 91.238100): 'Agartala',
    (25.202108, 75.809940): 'Kota',
    (25.623900, 85.108696): 'Patna',
    (26.186290, 91.776320): 'Guwahati',
    (26.818980, 80.930230): 'Lucknow',
    (26.959578, 70.921196): 'Jaisalmer',
    (28.435852, 95.113630): 'Geku',
    (28.646748, 77.274800): 'Delhi',
    (29.420034, 79.503460): 'Nainital',
    (31.599297, 74.910180): 'Amritsar',
    (32.161686, 77.158400): 'Manali',
    (33.989452, 77.977530): 'Ladakh',
    (34.059753, 74.812500): 'Srinagar'
}

#Defining a function to return the closest city by distance 
def get_closest_city(row):
    target_lat=row['latitude']
    target_lon=row['longitude']
    
    best_city = None
    min_distance=float('inf')
    
    # Loop through our dictionary to find the nearest match
    for(dict_lat,dict_lon),city in city_mapping.items():
        # Calculate the simple squared distance between the points
        distance=(target_lat-dict_lat)**2 +(target_lon-dict_lon)**2
        
        # Update if this is the closest city we've found so far
        if distance<min_distance:
            min_distance=distance
            best_city=city
    return best_city

# Apply our function to the dataframe
df['Cities']=df.apply(get_closest_city,axis=1)

#Show 10 sample cities
df[['latitude', 'longitude', 'Cities']].sample(10)
# Out:
#              latitude  longitude    Cities
# date
# 2025-12-15  29.420034  79.503460  Nainital
# 2024-08-21  19.086115  72.852910    Mumbai
# 2023-06-23  26.186290  91.776320  Guwahati
# 2019-12-01  25.623900  85.108696     Patna
# 2023-04-30  21.124779  79.115850    Nagpur
# 2020-03-27  21.124779  79.115850    Nagpur
# 2019-01-23  19.086115  72.852910    Mumbai
# 2024-07-22  21.124779  79.115850    Nagpur
# 2016-02-17  13.110721  80.245900   Chennai
# 2019-12-16  32.161686  77.158400    Manali

# %% [markdown]
# ## Matching Coordinates to City Names
#
# We wanted to match latitude and longitude coordinates to their correct city names.
#
# ### The Problem
#
# Computers often store decimal numbers with tiny hidden fractions (for example, `8.471002000000001` instead of `8.471002`).
#
# Because our code originally relied on an **exact numerical match**, these microscopic differences caused the lookup process to fail.
#
# We first tried rounding the numbers, but floating-point precision issues still introduced small hidden errors behind the scenes.
#
# ### The Solution
#
# Instead of forcing an exact match, we used a distance-based approach.
#
# A mathematical formula calculates the **physical distance** between coordinates, and the code simply selects the city that is geographically closest.
#
# ### Why This Works
#
# - Our 24 cities are far enough apart that the nearest match is unambiguous.
# - The method is robust against floating-point precision errors.
# - It avoids relying on fragile exact-number comparisons.
#
# As a result, the mapping is reliable and effectively immune to tiny decimal differences.

# %% [markdown]
# ## 🪨Performing Cyclic Encoding on months and days

# %%
#Extract basic time features
df['year']=df.index.year
df['month']=df.index.month
df['day']=df.index.day
df['day_of_year']=df.index.dayofyear


df['month_sin']=np.sin(2*np.pi *df['month']/12)
df['month_cos']=np.cos(2*np.pi *df['month']/12)

#Create cyclic features for day of yearv
df['day_sin']=np.sin(2*np.pi*df['day_of_year']/365.25)
df['day_cos']=np.cos(2*np.pi*df['day_of_year']/365.25)

display(df[['month', 'month_sin', 'month_cos']].tail(10))
# Out:
#             month     month_sin  month_cos
# date
# 2025-12-31     12 -2.449294e-16        1.0
# 2025-12-31     12 -2.449294e-16        1.0
# 2025-12-31     12 -2.449294e-16        1.0
# 2025-12-31     12 -2.449294e-16        1.0
# 2025-12-31     12 -2.449294e-16        1.0
# 2025-12-31     12 -2.449294e-16        1.0
# 2025-12-31     12 -2.449294e-16        1.0
# 2025-12-31     12 -2.449294e-16        1.0
# 2025-12-31     12 -2.449294e-16        1.0
# 2025-12-31     12 -2.449294e-16        1.0

# %% [markdown]
# ## 🔄 Why are we using Cyclical Encoding?
#
# Many time-related features such as **months, days, hours, or seasons** are cyclical in nature.
# This means the end of the cycle is close to the beginning (e.g., December is close to January).
#
# ---
#
# **If we use normal numerical encoding:**
#
# * ❌ January = 1
# * ❌ December = 12
#
# the model interprets them as **far apart**, even though they are actually adjacent in time. This creates **artificial discontinuities** and can harm model performance.
#
# ---
#
# ### 💡 Solution: Cyclical Encoding
#
# We transform cyclic features using **sine** and **cosine** functions:
#
# $$
# x = \sin\left(2\pi \cdot \frac{\text{value}}{\text{period}}\right)
# $$
#
# $$
# y = \cos\left(2\pi \cdot \frac{\text{value}}{\text{period}}\right)
# $$
#
# This maps each value onto a **unit circle**, where:
#
# * 📍 **nearby time points** remain close,
# * 🔄 the **start and end** of the cycle connect smoothly,
# * 📉 **seasonal patterns** become easier for models to learn.

# %%
plt.figure(figsize=(8,4))
plt.scatter(df.index.month, df['temperature_2m_mean'], alpha=0.5)
plt.title("Before: Linear Month Encoding")
plt.xlabel("Month (1-12)")
plt.ylabel("Temperature")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(df['month_cos'], df['month_sin'],
            c=df['temperature_2m_mean'], alpha=0.6)

plt.title("After: Cyclical Month Encoding")
plt.xlabel("month_cos")
plt.ylabel("month_sin")
plt.colorbar(label="Temperature")
plt.axis('equal')
plt.show()

# %% [markdown]
# ### <span style="color:lime">Before (Linear Encoding):</span>
# - Months are treated as straight numeric values (1 → 12).
#
# - December and January appear far apart.
#
# - Seasonal continuity is not preserved.
#
# ### <span style="color:lime">After (Cyclical Encoding):</span>
#
# - Months are mapped onto a circle using sin/cos.
#
# - December and January become neighbors.
#
# - Seasonal pattern becomes continuous and mathematically correct.

# %% [markdown]
# ## 🌍 Geospatial Visualization of Average Temperature Across Cities

# %%
import branca.colormap as cm
import folium 

#Calculating average temperature per City
city_avg_temp = df.groupby(['Cities', 'latitude', 'longitude'])['temperature_2m_mean'].mean().reset_index()


india_map = folium.Map(location=[22.0, 79.0], zoom_start=5, tiles='CartoDB positron')

#Mapping temperature->color
colormap = cm.LinearColormap(
    colors = ['navy', 'blue', 'lime', 'yellow', 'red'],
    vmin=city_avg_temp['temperature_2m_mean'].min(),
    vmax=city_avg_temp['temperature_2m_mean'].max()
)

#loops through each city and and assigns color based on temperature
for _, row in city_avg_temp.iterrows():
    color = colormap(row['temperature_2m_mean'])

    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=8,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.8,
        popup=f"<b>{row['Cities']}</b><br>Avg Temp: {row['temperature_2m_mean']:.2f}°C",
        tooltip=row['Cities']
    ).add_to(india_map)


colormap.caption = 'Average Temperature (°C)'
colormap.add_to(india_map)

india_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ce56030dd8037ec4f14614c3b370d47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ce56030dd8037ec4f14614c3b370d47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ce56030dd8037ec4f14614c3b370d47 = L.map(
#                 &quot;map_7ce56030dd8037ec4f14614c3b370d47&quot;,
#                 {
#                     center: [22.0, 79.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f30e31b15822fc51359102cb796c98d1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f30e31b15822fc51359102cb796c98d1.addTo(map_7ce56030dd8037ec4f14614c3b370d47);
#
#
#             var circle_marker_51a6d8174d9992f7a81645f9589f114b = L.circleMarker(
#                 [23.86643, 91.2381],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff5100ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff5100ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7ce56030dd8037ec4f14614c3b370d47);
#
#
#         var popup_6ed2e3e3aaaa41af11309074d297c76e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f28f44a3cf6ca4d929a6267a37707122 = $(`&lt;div id=&quot;html_f28f44a3cf6ca4d929a6267a37707122&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Agartala&lt;/b&gt;&lt;br&gt;Avg Temp: 25.03°C&lt;/div&gt;`)[0];
#                 popup_6ed2e3e3aaaa41af11309074d297c76e.setContent(html_f28f44a3cf6ca4d929a6267a37707122);
#
#
#
#         circle_marker_51a6d8174d9992f7a81645f9589f114b.bindPopup(popup_6ed2e3e3aaaa41af11309074d297c76e)
#         ;
#
#
#
#
#             circle_marker_51a6d8174d9992f7a81645f9589f114b.bindTooltip(
#                 `&lt;div&gt;
#                      Agartala
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_5fa521a1acf7bbf955b9345786de8f0e = L.circleMarker(
#                 [23.022846, 72.60188],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff1100ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff1100ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7ce56030dd8037ec4f14614c3b370d47);
#
#
#         var popup_fdb70bbeacb35a5a17728568277bf168 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2f36fd3d979bbebf7771956e0a30079 = $(`&lt;div id=&quot;html_a2f36fd3d979bbebf7771956e0a30079&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ahmedabad&lt;/b&gt;&lt;br&gt;Avg Temp: 27.42°C&lt;/div&gt;`)[0];
#                 popup_fdb70bbeacb35a5a17728568277bf168.setContent(html_a2f36fd3d979bbebf7771956e0a30079);
#
#
#
#         circle_marker_5fa521a1acf7bbf955b9345786de8f0e.bindPopup(popup_fdb70bbeacb35a5a17728568277bf168)
#         ;
#
#
#
#
#             circle_marker_5fa521a1acf7bbf955b9345786de8f0e.bindTooltip(
#                 `&lt;div&gt;
#                      Ahmedabad
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_d09252cd0a5ea4f9e7a791c9ff4f935d = L.circleMarker(
#                 [31.599297, 74.91018],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff8700ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff8700ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot

# %% [markdown]
# This visualization reveals clear geographical patterns in temperature distribution across cities.
#
# Warmer regions are concentrated in areas with lower latitudes indicating stronger heat retention and reduced coastal influence. In contrast, relatively cooler cities are either located at higher latitudes or closer to coastal regions where temperature moderation occurs due to surrounding water bodies.
#
# The color gradient highlights significant variation in average temperatures between cities, showing that climate conditions are not uniform across regions. Some cities consistently experience higher temperatures, indicating potential heat stress zones, while others maintain relatively stable and moderate climates.

# %%
df.isna().sum()
# Out:
# weather_code                        0
# temperature_2m_max                  0
# temperature_2m_min                  0
# apparent_temperature_max            0
# apparent_temperature_min            0
# sunshine_duration                   0
# daylight_duration                   0
# sunrise                             0
# sunset                              0
# precipitation_sum                   0
# rain_sum                            0
# snowfall_sum                        0
# precipitation_hours                 0
# shortwave_radiation_sum             0
# wind_direction_10m_dominant         0
# wind_speed_10m_max                  0
# et0_fao_evapotranspiration          0
# cloud_cover_max                     0
# cloud_cover_min                     0
# temperature_2m_mean                 0
# cloud_cover_mean                    0
# soil_moisture_0_to_100cm_mean       0
# dew_point_2m_mean                   0
# dew_point_2m_max                    0
# dew_point_2m_min                    0
# surface_pressure_min                0
# surface_pressure_max                0
# pressure_msl_min                    0
# pressure_msl_max                    0
# pressure_msl_mean                   0
# relative_humidity_2m_min            0
# relative_humidity_2m_max            0
# relative_humidity_2m_mean           0
# soil_temperature_0_to_100cm_mean    0
# wind_speed_10m_min                  0
# wind_speed_10m_mean                 0
# wet_bulb_temperature_2m_min         0
# wet_bulb_temperature_2m_max         0
# wet_bulb_temperature_2m_mean        0
# latitude                            0
# longitude                           0
# location_id                         0
# Cities                              0
# year                                0
# month                               0
# day                                 0
# day_of_year                         0
# month_sin                           0
# month_cos                           0
# day_sin                             0
# day_cos                             0
# dtype: int64

# %% [markdown]
# ## 📈 Temperature Change Analysis Across Cities (Year-wise Trend)

# %%
#Grouping Data Year-wise per city
yearly_temp = df.groupby(['Cities', 'year'])['temperature_2m_mean'].mean().unstack()

# Get first non-NaN value (from left)
first_year_values = yearly_temp.apply(lambda row: row.dropna().iloc[0], axis=1)

# Get last non-NaN value (from right)
last_year_values = yearly_temp.apply(lambda row: row.dropna().iloc[-1], axis=1)

# Compute change
yearly_temp['Temp_Change(°C)'] = last_year_values - first_year_values

# Rank
temp_change_ranking = yearly_temp[['Temp_Change(°C)']] \
    .sort_values(by='Temp_Change(°C)', ascending=False)

display(temp_change_ranking)
# Out:
# year                Temp_Change(°C)
# Cities
# Ahmedabad                  1.242776
# Manali                     1.085164
# Ladakh                     0.766962
# Agartala                   0.665395
# Mumbai                     0.652773
# Kolkata                    0.514601
# Chennai                    0.445256
# Geku                       0.442483
# Guwahati                   0.382595
# Jabalpur                   0.361008
# Delhi                      0.360177
# Nagpur                     0.354758
# Thiruvananthapuram         0.265184
# Patna                      0.213372
# Lucknow                    0.172120
# Hyderabad                  0.104816
# Bengaluru                 -0.044730
# Visakhapatnam             -0.153324
# Udupi                     -0.346307
# Srinagar                  -0.594280
# Amritsar                  -0.803016
# Kota                      -0.871909
# Jaisalmer                 -1.054300
# Nainital                  -1.570435

# %% [markdown]
# Cities with the highest positive change indicate significant warming, suggesting increasing heat intensity in those regions. On the other hand, cities with little or negative change show relatively stable or cooling patterns.

# %% [markdown]
# ## 🔥 Heatwave Analysis: Extreme Temperature Days Across Cities

# %%
import plotly.express as px

# %%
df['is_extreme_heat'] = df['temperature_2m_max'] > 40.0

heatwave_counts = df.groupby('Cities')['is_extreme_heat'].sum().reset_index()
heatwave_counts.rename(columns={'is_extreme_heat': 'Total_Heatwave_Days'}, inplace=True)

heatwave_counts = heatwave_counts.sort_values(by='Total_Heatwave_Days', ascending=False)

fig = px.bar(
    heatwave_counts[heatwave_counts['Total_Heatwave_Days'] > 0],
    x='Cities', 
    y='Total_Heatwave_Days',
    title='Total Number of Days Exceeding 40°C (2016-2025)',
    color='Total_Heatwave_Days',
    color_continuous_scale='Reds'
)
fig.show()

# %% [markdown]
# Cities with a higher number of days where temperatures exceeded 40°C are more prone to heatwaves, indicating greater exposure to extreme temperature conditions and potential risks to human health, infrastructure, and energy demand.

# %% [markdown]
# ## 🌧️Rainfall Analysis

# %% [markdown]
# ### Year-wise Rainfall Trend Analysis Across Cities

# %%
#Calculate yearly total rainfall per city
yearly_rainfall = df.groupby(['Cities', 'year'])['precipitation_sum'].sum().reset_index()

#Create pivot table (cities as rows, years as columns)
rainfall_pivot = yearly_rainfall.pivot(index='Cities', columns='year', values='precipitation_sum')
fig = px.line(
    yearly_rainfall,
    x='year',
    y='precipitation_sum',
    facet_col='Cities',        # creates separate plot for each city
    facet_col_wrap=4,          # number of plots per row
    title='Year-wise Rainfall Trend per City',
    markers=True
)

# Improve spacing and readability
fig.update_layout(
    height=800,
    width=1200,
    showlegend=False
)

fig.show()

# %% [markdown]
# ### 📊 Rainfall Change Ranking Across Cities

# %%
#Create yearly rainfall pivot table
rainfall_pivot = yearly_rainfall.pivot(index='Cities', columns='year', values='precipitation_sum')

#Get first available year rainfall
first_year_rain = rainfall_pivot.apply(lambda row: row.dropna().iloc[0], axis=1)

#Get last available year rainfall
last_year_rain = rainfall_pivot.apply(lambda row: row.dropna().iloc[-1], axis=1)

#Calculate change
rainfall_pivot['Rainfall_Change(mm)'] = last_year_rain - first_year_rain

#Rank cities
rainfall_change_ranking = rainfall_pivot[['Rainfall_Change(mm)']] \
    .sort_values(by='Rainfall_Change(mm)', ascending=False)

display(rainfall_change_ranking)
# Out:
# year                Rainfall_Change(mm)
# Cities
# Udupi                            2300.8
# Manali                           1125.6
# Guwahati                          771.5
# Thiruvananthapuram                703.9
# Chennai                           685.4
# Amritsar                          608.8
# Visakhapatnam                     438.8
# Kolkata                           395.3
# Ladakh                            284.4
# Agartala                          267.2
# Bengaluru                         259.3
# Jabalpur                          235.9
# Ahmedabad                         233.4
# Patna                              92.6
# Jaisalmer                          92.1
# Mumbai                             29.5
# Kota                               27.1
# Delhi                             -12.1
# Nagpur                            -65.5
# Hyderabad                        -129.1
# Lucknow                          -188.5
# Nainital                         -290.5
# Geku                            -1039.8
# Srinagar                        -1097.3

# %% [markdown]
# Cities like Udupi, Manali, and Guwahati show a significant increase in rainfall, indicating stronger monsoon influence and a higher potential risk of flooding in recent years. These regions may experience more extreme rainfall events and variability.
#
# On the other hand, cities such as Srinagar, Geku, and Nainital show a decrease in rainfall, suggesting drying trends and increasing vulnerability to drought conditions. This indicates uneven climate impacts across regions.

# %% [markdown]
# ### 🌊 Rainfall vs Normal Rainfall Analysis

# %%
# Calculate yearly rainfall first
yearly_rainfall = df.groupby(['Cities', 'year'])['precipitation_sum'].sum().reset_index()

# Calculate NORMAL yearly rainfall 
normal_rainfall = yearly_rainfall.groupby('Cities')['precipitation_sum'].mean().reset_index()
normal_rainfall.rename(columns={'precipitation_sum': 'Normal_Rainfall'}, inplace=True)

#Merge
rainfall_comparison = pd.merge(yearly_rainfall, normal_rainfall, on='Cities')

#Difference
rainfall_comparison['Difference'] = rainfall_comparison['precipitation_sum'] - rainfall_comparison['Normal_Rainfall']

#Classification
def classify_rainfall(diff):
    if diff > 0:
        return 'Above Normal (Flood Risk)'
    elif diff < 0:
        return 'Below Normal (Drought Risk)'
    else:
        return 'Normal'

rainfall_comparison['Rainfall_Status'] = rainfall_comparison['Difference'].apply(classify_rainfall)

display(rainfall_comparison.sample(10))
# Out:
#                  Cities  year  precipitation_sum  Normal_Rainfall  Difference  \
# 163            Nainital  2017             1918.3          1770.70      147.60
# 140              Manali  2024             2715.0          2542.89      172.11
# 39              Chennai  2018              844.4          1357.33     -512.93
# 144              Mumbai  2018             1361.4          2400.35    -1038.95
# 79            Hyderabad  2024             1299.1           922.91      376.19
# 166            Nainital  2020             1779.0          1770.70        8.30
# 124             Lucknow  2018             1228.3          1086.76      141.54
# 161              Nagpur  2025             1367.5          1432.51      -65.01
# 126             Lucknow  2020             1296.1          1086.76      209.34
# 191  Thiruvananthapuram  2018             2432.3          2286.41      145.89
#
#                  Rainfall_Status
# 163    Above Normal (Flood Risk)
# 140    Above Normal (Flood Risk)
# 39   Below Normal (Drought Risk)
# 144  Below Normal (Drought Risk)
# 79     Above Normal (Flood Risk)
# 166    Above Normal (Flood Risk)
# 124    Above Normal (Flood Risk)
# 161  Below Normal (Drought Risk)
# 126    Above Normal (Flood Risk)
# 191    Above Normal (Flood Risk)

# %% [markdown]
# It identifies years where rainfall deviates from the normal average, indicating potential flood and drought risks. Years with above-normal rainfall suggest increased chances of flooding due to excess precipitation, while below-normal years indicate possible drought conditions due to rainfall deficiency.
#
# However, this represents relative risk based on deviation from normal rainfall and does not directly confirm actual flood or drought events. Additional factors such as rainfall intensity and duration are required for precise event detection.

# %% [markdown]
# **Yearly rainfall trends help identify long-term changes in precipitation patterns, while comparison with normal rainfall highlights year-specific anomalies indicating potential flood or drought risks. Together, they provide a comprehensive understanding of both climate trends and variability.**
